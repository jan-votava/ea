# %% [markdown]
# # CZEA Fellowships Statistics

# %% [markdown]
# ## Spring 2023 Fellowships Evaluation
#
# ### Record numbers
#
# The last run of our EA fellowships was by far the most successful in terms of number of applications (77) and participants (54). (See Figure 1). We hit the record also in number of completions (people who attended 6 or more sessions in a seminar - 31). We think the cause of the success was better marketing.
#
# ### Suboptimal completion rate
#
# We could improve in completion rate (the percentage of people who get from the apllication to attending 6 or more sessions in a seminar), which was 40 % - better than the previous run, but significantly worse than in our first runs (see Figure 2). One factor causing lower completion rate could be that the cohorts often are not small and it is not always strictly determined who belongs to which cohort, which makes people feel less responsibility toward their group.
#
# ### Focus on practical application
#
# We worked to improve our fellowships by adding opportunities for participants to focus not only on reading and discussions, but also on practical application. We ran the first iteration of our career seminar and complemented our AI safety fellowship with the option to attend extra sessions and do projects with us. More than 10 participants joined us in the project phase. We primarily focused on writing LLM evals related to manipulation. We had a few people in AI safety seminar who could plausibly help with AI safety research in future.
#
# ### AI governance fellowship
#
# We also ran AI governance version of our AI safety fellowship for the first time. We planned to have it already in fall 2022, but it was canceled for organisational reasons. (For data on different seminars we have been offering see Tables 2 and 3.)
#
# ### Some higher profile participants
#
# At least two higher profile people participated in our technical AI safety seminar (one academic researching ML computational linguistics, who is also active in popularization of AI in Czechia, and a member of a top team focused on creating conversational AI). They are not aligned with our more long-term existential risk perspective, but they got familiar with the materials and arguments from AGI Alignment curriculum. (One said that he changed some opinions, the other was more critical and didn't like that the syllabus didn't cover near term issues, but he appreciated communication with our facilitator.)

# %%
report_df[["Applications", "Participants", "Completions (6 or more sessions)"]].drop("2023 fall").plot.bar(title="Figure 1: Applications, participants, completions by seasons")
# Out:
# <Axes: title={'center': 'Figure 1: Applications, participants, completions by seasons'}>

# %%
report_df["Completions rate"].drop("2023 fall").plot.bar(title="Figure 2: Completion rate by seasons")
# Out:
# <Axes: title={'center': 'Figure 2: Completion rate by seasons'}>

# %% [markdown]
# ### Table 1: CZEA Fellowships, comparison of runs (spring 2021 - fall 2023)

# %%
report_df
# Out:
#              Applications Participants Completions (6 or more sessions)  \
# 2021 spring            42           30                               24
# 2021 fall              33           23                               16
# 2022 spring            44           28                               20
# 2022 fall              51           36                               16
# 2023 spring            78           54                               31
# 2023 fall              24
#
#             Total attendance Mean attendance Dropout Completions rate  \
# 2021 spring              199             4.9    28.6             57.1
# 2021 fall                133             4.6    30.3             48.5
# 2022 spring              167             3.8    36.4             45.5
# 2022 fall                183             3.8    29.4             31.4
# 2023 spring              273             3.5    30.8             39.7
# 2023 fall
#
#             Survey responses Influence on decisions Willingness to recommend  \
# 2021 spring                8                    8.2                      9.6
# 2021 fall                 11                    6.9                      9.5
# 2022 spring               12                    6.7                      9.4
# 2022 fall                  6                    6.5                      8.3
# 2023 spring               26                    7.1                      9.0
# 2023 fall
#
#             Facilitator evaluation
# 2021 spring                    9.0
# 2021 fall                      9.6
# 2022 spring                    9.2
# 2022 fall                      7.7
# 2023 spring                    9.2
# 2023 fall

# %% [markdown]
# ### Table 2: Differrent seminars we have been offering since 2021
# (Absolute and relative numbers of applications)

# %%
report_2_columns("Season","Seminar")
# Out:
#             AI safety seminář Prague Season seminář  \
# 2021 jaro                   0                     0
# 2021 podzim                 0                     0
# 2022 jaro                   0                     0
# 2022 podzim        22 / 33.3%            22 / 33.3%
# 2023 jaro          43 / 49.4%                     0
# 2023 podzim        13 / 50.0%                     0
#
#             seminář Kariéra s pozitivním dopadem  \
# 2021 jaro                                      0
# 2021 podzim                                    0
# 2022 jaro                                      0
# 2022 podzim                                    0
# 2023 jaro                             12 / 13.8%
# 2023 podzim                            4 / 15.4%
#
#             úvodní Seminář o efektivním altruismu
# 2021 jaro                             42 / 100.0%
# 2021 podzim                           33 / 100.0%
# 2022 jaro                             44 / 100.0%
# 2022 podzim                            22 / 33.3%
# 2023 jaro                              32 / 36.8%
# 2023 podzim                             9 / 34.6%

# %% [markdown]
# ### Table 3: Two versions of AI safety seminar

# %%
column_final_report("AI seminar")
# Out:
#                                 Applications  Participants  Completions  \
# AI Governance Curriculum                  27            13            6
# Technical Alignment Curriculum            50            33           22
#
#                                 Total attendance  Mean attendance  Dropout  \
# AI Governance Curriculum                      54              2.5     40.9
# Technical Alignment Curriculum               181              4.4     21.4
#
#                                 Completions rate  Survey responses  \
# AI Governance Curriculum                    27.3                 5
# Technical Alignment Curriculum              52.4                13
#
#                                 Influence on decisions  \
# AI Governance Curriculum                           6.6
# Technical Alignment Curriculum                     6.8
#
#                                 Willingness to recommend  \
# AI Governance Curriculum                             9.0
# Technical Alignment Curriculum                       8.5
#
#                                 Facilitator evaluation
# AI Governance Curriculum                           8.6
# Technical Alignment Curriculum                     8.8

# %% [markdown]
# ### Comparison of seasons: more detailed statistics

# %%
report_2_columns("Season","Facilitator")
# Out:
#               Ada Böhm Anna Gajdová Hana Kalivodová Jakub Halmeš  \
# 2021 jaro            0     4 / 9.5%               0            0
# 2021 podzim          0            0       4 / 14.8%            0
# 2022 jaro            0            0               0            0
# 2022 podzim  8 / 21.6%            0       4 / 10.8%            0
# 2023 jaro     4 / 5.4%            0      14 / 18.9%     6 / 8.1%
# 2023 podzim          0            0               0            0
#
#             Jakub Sechter  Jan Votava Jiří Nádvorník Martin Račák  \
# 2021 jaro               0  14 / 33.3%     10 / 23.8%     3 / 7.1%
# 2021 podzim     3 / 11.1%           0      3 / 11.1%    5 / 18.5%
# 2022 jaro               0  12 / 36.4%      5 / 15.2%            0
# 2022 podzim             0   6 / 16.2%              0            0
# 2023 jaro      11 / 14.9%  29 / 39.2%              0            0
# 2023 podzim             0           0              0            0
#
#             Matej Vrzala Michal Keda Pavel Minárik Přemek Paška Tomáš Dulka  \
# 2021 jaro       3 / 7.1%           0             0     4 / 9.5%           0
# 2021 podzim            0   5 / 18.5%             0    4 / 14.8%   3 / 11.1%
# 2022 jaro              0    3 / 9.1%     4 / 12.1%            0           0
# 2022 podzim            0   5 / 13.5%             0    4 / 10.8%    3 / 8.1%
# 2023 jaro              0    4 / 5.4%             0     6 / 8.1%           0
# 2023 podzim            0           0             0            0           0
#
#             Tomáš Turlík Vojtěch Brynych
# 2021 jaro              0        4 / 9.5%
# 2021 podzim            0               0
# 2022 jaro      4 / 12.1%       5 / 15.2%
# 2022 podzim            0       7 / 18.9%
# 2023 jaro              0               0
# 2023 podzim            0               0

# %%
report_2_columns("Season","City")
# Out:
#                Beroun Bratislava        Brno      Děčín   Olomouc     Plzeň  \
# 2021 jaro    1 / 2.9%          0    3 / 8.8%   1 / 2.9%         0  1 / 2.9%
# 2021 podzim         0   1 / 3.6%   7 / 25.0%  3 / 10.7%  1 / 3.6%         0
# 2022 jaro           0          0  11 / 28.2%          0  3 / 7.7%         0
# 2022 podzim         0          0  11 / 23.9%          0         0  1 / 2.2%
# 2023 jaro    1 / 1.4%          0  17 / 23.3%          0         0  1 / 1.4%
# 2023 podzim         0   1 / 4.2%   9 / 37.5%          0  1 / 4.2%         0
#
#             Považská Bystrica       Praha
# 2021 jaro                   0  28 / 82.4%
# 2021 podzim          1 / 3.6%  15 / 53.6%
# 2022 jaro            1 / 2.6%  24 / 61.5%
# 2022 podzim                 0  34 / 73.9%
# 2023 jaro                   0  54 / 74.0%
# 2023 podzim                 0  13 / 54.2%

# %%
report_2_columns("Season","Format")
# Out:
#               in person       online
# 2021 jaro             0  42 / 100.0%
# 2021 podzim  17 / 54.8%   14 / 45.2%
# 2022 jaro    31 / 70.5%   13 / 29.5%
# 2022 podzim  30 / 75.0%   10 / 25.0%
# 2023 jaro    54 / 70.1%   23 / 29.9%
# 2023 podzim  19 / 79.2%    5 / 20.8%

# %%
report_2_columns("Season","Age")
# Out:
#             15 - 20 let 20 - 24 let 25 - 29 let 30 - 35 let víc než 35 let
# 2021 jaro      2 / 4.8%  13 / 31.0%  16 / 38.1%   8 / 19.0%       3 / 7.1%
# 2021 podzim    1 / 3.0%   9 / 27.3%  10 / 30.3%   7 / 21.2%      6 / 18.2%
# 2022 jaro      2 / 4.5%  17 / 38.6%   7 / 15.9%   9 / 20.5%      9 / 20.5%
# 2022 podzim    1 / 2.0%  15 / 30.6%   9 / 18.4%  14 / 28.6%     10 / 20.4%
# 2023 jaro      2 / 2.6%   9 / 11.7%  20 / 26.0%  25 / 32.5%     21 / 27.3%
# 2023 podzim   3 / 13.0%   5 / 21.7%   4 / 17.4%   4 / 17.4%      7 / 30.4%

# %%
report_2_columns("Season","Gender")
# Out:
#                       F           M
# 2021 jaro    23 / 54.8%  19 / 45.2%
# 2021 podzim  17 / 51.5%  16 / 48.5%
# 2022 jaro    26 / 59.1%  18 / 40.9%
# 2022 podzim  17 / 33.3%  34 / 66.7%
# 2023 jaro    32 / 41.6%  45 / 58.4%
# 2023 podzim   4 / 17.4%  19 / 82.6%

# %%
df.loc[df["Jak jste se o semináři dozvěděli?"].str.contains("FB, i když český EA zde nesleduji", na=False), "Jak jste se o semináři dozvěděli?"] = "FB i když český EA zde nesleduji"
report_2_columns("Season","Jak jste se o semináři dozvěděli?")
# Out:
#             FB i když český EA zde nesleduji      jinak     leták  \
# 2021 jaro                                  0          0         0
# 2021 podzim                                0          0         0
# 2022 jaro                         13 / 32.5%          0  3 / 7.5%
# 2022 podzim                         1 / 2.1%  6 / 12.8%  1 / 2.1%
# 2023 jaro                         13 / 17.6%   7 / 9.5%  1 / 1.4%
# 2023 podzim                                0   2 / 9.5%         0
#
#             osobní doporučení přednáška sleduji vás na FB spolkový newsletter  \
# 2021 jaro                   0         0                 0                   0
# 2021 podzim                 0         0                 0                   0
# 2022 jaro          15 / 37.5%         0         8 / 20.0%                   0
# 2022 podzim        24 / 51.1%         0        10 / 21.3%                   0
# 2023 jaro          15 / 20.3%  3 / 4.1%        23 / 31.1%            4 / 5.4%
# 2023 podzim         8 / 38.1%  2 / 9.5%          1 / 4.8%            1 / 4.8%
#
#             web Spolku pro efektivní altruismus
# 2021 jaro                                     0
# 2021 podzim                                   0
# 2022 jaro                              1 / 2.5%
# 2022 podzim                           5 / 10.6%
# 2023 jaro                             8 / 10.8%
# 2023 podzim                           7 / 33.3%

# %%
report_2_columns("Season","AI seminar")
# Out:
#             AI Governance Curriculum Technical Alignment Curriculum
# 2021 jaro                          0                              0
# 2021 podzim                        0                              0
# 2022 jaro                          0                              0
# 2022 podzim                6 / 27.3%                     16 / 72.7%
# 2023 jaro                 16 / 38.1%                     26 / 61.9%
# 2023 podzim                5 / 38.5%                      8 / 61.5%

# %% [markdown]
# ## All seasons statistics (2021 - 2023)

# %% [markdown]
# ### All Seasons, basic statistics

# %%
report_df = report(df,"All seasons")
report_df = report_df.rename(columns={"Completions":"Completions (6 or more sessions)"})
report_df[["Applications", "Participants", "Completions (6 or more sessions)"]].transpose().plot.bar(title="Figure 1: Applications, participants, completions since 2021")
report_df
# Out:
#              Applications  Participants  Completions (6 or more sessions)  \
# All seasons           272           171                               107
#
#              Total attendance  Mean attendance  Dropout  Completions rate  \
# All seasons               955              4.0     31.0              43.1
#
#              Survey responses  Influence on decisions  \
# All seasons                63                     7.1
#
#              Willingness to recommend  Facilitator evaluation
# All seasons                       9.2                     9.1

# %% [markdown]
# ### All Seasons, detailed statistics

# %%
column_final_report("Seminar")
# Out:
#                                        Applications  Participants  \
# AI safety seminář                                78            47
# Prague Season seminář                            22            13
# seminář Kariéra s pozitivním dopadem             16             9
# úvodní Seminář o efektivním altruismu           182           120
#
#                                        Completions  Total attendance  \
# AI safety seminář                               29               242
# Prague Season seminář                            3                53
# seminář Kariéra s pozitivním dopadem             4                44
# úvodní Seminář o efektivním altruismu           77               688
#
#                                        Mean attendance  Dropout  \
# AI safety seminář                                  3.8     27.7
# Prague Season seminář                              2.6     40.9
# seminář Kariéra s pozitivním dopadem               3.7     25.0
# úvodní Seminář o efektivním altruismu              4.1     30.6
#
#                                        Completions rate  Survey responses  \
# AI safety seminář                                  44.6                17
# Prague Season seminář                              13.6                 2
# seminář Kariéra s pozitivním dopadem               33.3                 2
# úvodní Seminář o efektivním altruismu              44.5                44
#
#                                        Influence on decisions  \
# AI safety seminář                                         6.8
# Prague Season seminář                                     7.5
# seminář Kariéra s pozitivním dopadem                      8.0
# úvodní Seminář o efektivním altruismu                     7.1
#
#                                        Willingness to recommend  \
# AI safety seminář                                           8.6
# Prague Season seminář                                       9.5
# seminář Kariéra s pozitivním dopadem                       10.0
# úvodní Seminář o efektivním altruismu                       9.3
#
#                                        Facilitator evaluation
# AI safety seminář                                         8.8
# Prague Season seminář                                     8.5
# seminář Kariéra s pozitivním dopadem                     10.0
# úvodní Seminář o efektivním altruismu                     9.2

# %%
column_final_report("Facilitator")
# Out:
#                  Applications  Participants  Completions  Total attendance  \
# Ada Böhm                   12            11            5                51
# Anna Gajdová                4             3            3                23
# Hana Kalivodová            22            18           10                86
# Jakub Halmeš                6             6            4                30
# Jakub Sechter              14            10            6                56
# Jan Votava                 61            53           31               282
# Jiří Nádvorník             18            17           14               116
# Martin Račák                8             7            4                31
# Matej Vrzala                3             2            2                16
# Michal Keda                17            16            8                86
# Pavel Minárik               4             3            2                18
# Přemek Paška               18            11            8                63
# Tomáš Dulka                 6             6            6                44
# Tomáš Turlík                4             3            3                19
# Vojtěch Brynych            16            10            6                58
#
#                  Mean attendance  Dropout  Completions rate  Survey responses  \
# Ada Böhm                     4.6      8.3              41.7                 3
# Anna Gajdová                 5.8     25.0              75.0                 1
# Hana Kalivodová              3.9     18.2              45.5                 6
# Jakub Halmeš                 5.0      0.0              66.7                 5
# Jakub Sechter                4.0     28.6              42.9                 2
# Jan Votava                   4.6     13.1              50.8                23
# Jiří Nádvorník               6.4      5.6              77.8                 8
# Martin Račák                 3.9     12.5              50.0                 3
# Matej Vrzala                 5.3     33.3              66.7                 0
# Michal Keda                  5.1      5.9              47.1                 6
# Pavel Minárik                4.5     25.0              50.0                 1
# Přemek Paška                 4.8     38.9              44.4                 3
# Tomáš Dulka                  7.3      0.0             100.0                 4
# Tomáš Turlík                 4.8     25.0              75.0                 1
# Vojtěch Brynych              3.6     37.5              37.5                 1
#
#                 Influence on decisions Willingness to recommend  \
# Ada Böhm                           6.0                      6.3
# Anna Gajdová                       8.0                     10.0
# Hana Kalivodová                    6.3                      9.3
# Jakub Halmeš                       7.4                      9.4
# Jakub Sechter                      8.0                      9.0
# Jan Votava                         7.2                      9.4
# Jiří Nádvorník                     7.2                      9.5
# Martin Račák                       7.7                      9.7
# Matej Vrzala
# Michal Keda                        6.3                      8.0
# Pavel Minárik                     10.0                     10.0
# Přemek Paška                       7.7                      9.7
# Tomáš Dulka                        6.0                      8.8
# Tomáš Turlík                       7.0                      9.0
# Vojtěch Brynych                   10.0                     10.0
#
#                 Facilitator evaluation
# Ada Böhm                           8.3
# Anna Gajdová                      10.0
# Hana Kalivodová                    8.8
# Jakub Halmeš                       9.8
# Jakub Sechter                     10.0
# Jan Votava                         9.4
# Jiří Nádvorník                     9.2
# Martin Račák                       9.0
# Matej Vrzala
# Michal Keda                        8.8
# Pavel Minárik                      8.0
# Přemek Paška                       9.7
# Tomáš Dulka                        7.8
# Tomáš Turlík                       8.0
# Vojtěch Brynych                   10.0

# %%
column_final_report("City")
# Out:
#                    Applications  Participants  Completions  Total attendance  \
# Beroun                        2             1            1                 6
# Bratislava                    2             1            1                 7
# Brno                         58            39           23               208
# Děčín                         4             4            4                32
# Olomouc                       5             2            0                 6
# Plzeň                         3             3            2                18
# Považská Bystrica             2             2            2                13
# Praha                       168           102           65               573
#
#                    Mean attendance  Dropout  Completions rate  \
# Beroun                         3.0     50.0              50.0
# Bratislava                     7.0      0.0             100.0
# Brno                           4.3     20.4              46.9
# Děčín                          8.0      0.0             100.0
# Olomouc                        1.5     50.0               0.0
# Plzeň                          6.0      0.0              66.7
# Považská Bystrica              6.5      0.0             100.0
# Praha                          3.8     34.2              41.9
#
#                    Survey responses Influence on decisions  \
# Beroun                            0
# Bratislava                        1                    9.0
# Brno                             17                    6.7
# Děčín                             2                    9.0
# Olomouc                           0
# Plzeň                             1                    8.0
# Považská Bystrica                 0
# Praha                            35                    7.0
#
#                   Willingness to recommend Facilitator evaluation
# Beroun
# Bratislava                             9.0                   10.0
# Brno                                   8.7                    8.9
# Děčín                                 10.0                   10.0
# Olomouc
# Plzeň                                 10.0                   10.0
# Považská Bystrica
# Praha                                  9.2                    9.0

# %%
column_final_report("Format")
# Out:
#            Applications  Participants  Completions  Total attendance  \
# in person           151            95           57               512
# online              107            67           47               400
#
#            Mean attendance  Dropout  Completions rate  Survey responses  \
# in person              4.0     28.0              43.2                37
# online                 4.1     34.3              46.1                23
#
#            Influence on decisions  Willingness to recommend  \
# in person                     6.7                       8.9
# online                        7.7                       9.6
#
#            Facilitator evaluation
# in person                     9.0
# online                        9.3

# %%
column_final_report("Age")
# Out:
#                 Applications  Participants  Completions  Total attendance  \
# 15 - 20 let               11             8            6                49
# 20 - 24 let               68            40           23               215
# 25 - 29 let               66            46           34               286
# 30 - 35 let               67            44           23               225
# víc než 35 let            56            32           21               176
#
#                 Mean attendance  Dropout  Completions rate  Survey responses  \
# 15 - 20 let                 6.1      0.0              75.0                 1
# 20 - 24 let                 3.5     36.5              36.5                11
# 25 - 29 let                 4.8     25.8              54.8                16
# 30 - 35 let                 3.7     30.2              36.5                17
# víc než 35 let              3.7     34.7              42.9                17
#
#                 Influence on decisions  Willingness to recommend  \
# 15 - 20 let                        3.0                       7.0
# 20 - 24 let                        6.8                       9.2
# 25 - 29 let                        7.1                       9.0
# 30 - 35 let                        7.5                       9.6
# víc než 35 let                     7.1                       9.1
#
#                 Facilitator evaluation
# 15 - 20 let                        9.0
# 20 - 24 let                        8.8
# 25 - 29 let                        9.2
# 30 - 35 let                        8.9
# víc než 35 let                     9.5

# %%
column_final_report("Gender")
# Out:
#    Applications  Participants  Completions  Total attendance  Mean attendance  \
# F           119            70           44               391              3.4
# M           151           101           63               564              4.5
#
#    Dropout  Completions rate  Survey responses  Influence on decisions  \
# F     39.1              38.3                22                     7.0
# M     23.5              47.7                40                     7.2
#
#    Willingness to recommend  Facilitator evaluation
# F                       9.3                     9.4
# M                       9.1                     9.0

# %%
df.loc[df["Jak jste se o semináři dozvěděli?"].str.contains("FB, i když český EA zde nesleduji", na=False), "Jak jste se o semináři dozvěděli?"] = "FB i když český EA zde nesleduji"
column_final_report("Jak jste se o semináři dozvěděli?")
# Out:
#                                      Applications  Participants  Completions  \
# FB i když český EA zde nesleduji               27            11            6
# jinak                                          15            11            4
# leták                                           5             4            2
# osobní doporučení                              62            43           24
# přednáška                                       5             3            2
# sleduji vás na FB                              42            29           19
# spolkový newsletter                             5             3            2
# web Spolku pro efektivní altruismus            21             9            5
#
#                                      Total attendance  Mean attendance  \
# FB i když český EA zde nesleduji                   60              2.2
# jinak                                              45              3.5
# leták                                              17              3.4
# osobní doporučení                                 235              4.4
# přednáška                                          18              6.0
# sleduji vás na FB                                 154              3.8
# spolkový newsletter                                17              4.2
# web Spolku pro efektivní altruismus                49              4.1
#
#                                      Dropout  Completions rate  \
# FB i když český EA zde nesleduji        59.3              22.2
# jinak                                   15.4              30.8
# leták                                   20.0              40.0
# osobní doporučení                       20.4              44.4
# přednáška                                0.0              66.7
# sleduji vás na FB                       29.3              46.3
# spolkový newsletter                     25.0              50.0
# web Spolku pro efektivní altruismus     35.7              35.7
#
#                                      Survey responses  Influence on decisions  \
# FB i když český EA zde nesleduji                    5                     8.6
# jinak                                               3                     4.7
# leták                                               1                     7.0
# osobní doporučení                                  14                     7.6
# přednáška                                           1                     8.0
# sleduji vás na FB                                  12                     6.2
# spolkový newsletter                                 1                     9.0
# web Spolku pro efektivní altruismus                 3                     7.0
#
#                                      Willingness to recommend  \
# FB i když český EA zde nesleduji                          9.4
# jinak                                                     9.0
# leták                                                     9.0
# osobní doporučení                                         9.0
# přednáška                                                 8.0
# sleduji vás na FB                                         8.8
# spolkový newsletter                                      10.0
# web Spolku pro efektivní altruismus                       9.3
#
#                                      Facilitator evaluation
# FB i když český EA zde nesleduji                        9.6
# jinak                                                   7.0
# leták                                                   8.0
# osobní doporučení                                       9.3
# přednáška                                              10.0
# sleduji vás na FB                                       8.7
# spolkový newsletter                                    10.0
# web Spolku pro efektivní altruismus                     9.0

# %%
column_final_report("Persona")
# Out:
#                Applications  Participants  Completions  Total attendance  \
# AI Researcher            13            13            8                62
# Podnikavec               12            12            9                76
# Policnik                 12            10            7                58
# Vědec                     4             3            3                23
#
#                Mean attendance  Dropout  Completions rate  Survey responses  \
# AI Researcher              4.8      0.0              61.5                 6
# Podnikavec                 6.3      0.0              75.0                 5
# Policnik                   4.8     16.7              58.3                 3
# Vědec                      5.8     25.0              75.0                 1
#
#                Influence on decisions  Willingness to recommend  \
# AI Researcher                     7.3                       8.0
# Podnikavec                        8.2                       9.4
# Policnik                          8.3                       9.7
# Vědec                             9.0                       9.0
#
#                Facilitator evaluation
# AI Researcher                     8.8
# Podnikavec                        9.8
# Policnik                          9.7
# Vědec                             9.0

# %%
column_final_report("Causes")
# Out:
#              Applications  Participants  Completions  Total attendance  \
# AI Safety              10            10            7                56
# Biorisks                3             2            2                14
# Environment             2             2            1                11
#
#              Mean attendance  Dropout  Completions rate  Survey responses  \
# AI Safety                5.6      0.0              70.0                 6
# Biorisks                 4.7     33.3              66.7                 1
# Environment              5.5      0.0              50.0                 0
#
#             Influence on decisions Willingness to recommend  \
# AI Safety                      7.3                      8.0
# Biorisks                       8.0                      9.0
# Environment
#
#             Facilitator evaluation
# AI Safety                      9.0
# Biorisks                      10.0
# Environment

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

def get_data(data_file, columns_file):
    input_path = os.path.join(os.getcwd(), "datasets")
    columns = pd.read_csv(os.path.join(input_path, columns_file), sep="\t", header=None)
    columns = columns[0].str.partition(" (from ")[0].tolist()
    columns.insert(0, "Name")
    return pd.read_csv(os.path.join(input_path, data_file), sep="\t", names=columns)

data_file = "Untitled spreadsheet - Sheet1.tsv"
columns_file = "Untitled spreadsheet - Sheet2.tsv"
df = get_data(data_file, columns_file)

def report(df, index, df0=df):
    report_df = pd.DataFrame(index=[index])
    report_df['Applications'] = len(df)
    report_df['Participants'] = len(df[df['Participation'] > 0])
    report_df['Completions'] = len(df[df['Participation'] > 5])
    report_df['Total attendance'] = int(df['Participation'].sum())

    seasons_list = sorted(df0.Season.unique())
    past_seasons_filter = df.Season != seasons_list[-1]
    past_seasons_df = df[past_seasons_filter]
    participation_filter = past_seasons_df['Participation'] > 0
    completion_filter = past_seasons_df['Participation'] > 5

    questions = ['Influence on decisions', 'Willingness to recommend', 'Facilitator evaluation']

    if len(past_seasons_df[participation_filter]) > 0:
        report_df['Mean attendance'] = df['Participation'].mean().round(1)
        report_df['Dropout'] = (len(past_seasons_df) - len(past_seasons_df[participation_filter])) / len(past_seasons_df) * 100
        report_df['Completions rate'] = len(past_seasons_df[completion_filter]) / len(past_seasons_df) * 100
        report_df['Dropout'] = report_df.Dropout.round(1)
        report_df['Completions rate'] = report_df['Completions rate'].round(1)

        survey = len(df[df[questions[0]].notna()])
        report_df['Survey responses'] = survey
        for question in questions:
            if survey > 0:
                if df[question].dtype == 'object':
                    df = df.copy()
                    df.loc[:, question] = df[question].astype(str)
                    df.loc[df[question].str.contains("10 - určitě ano", na=False), question] = 10
                    df.loc[:,question] = pd.to_numeric(df[question], errors='coerce')
                report_df[question] = df[question].mean().round(1)
            else:  
                report_df[question] = ""

    else:
        report_df[['Dropout','Mean attendance','Completions rate','Participants','Completions','Total attendance', 'Survey responses', 'Influence on decisions', 'Willingness to recommend', 'Facilitator evaluation']] = ""

    return report_df

def items_list(series):
    split_series = series.str.split(', ')
    items_list = split_series.explode().value_counts().reset_index()
    items_list.columns = ['Item', 'Count']
    items_list = items_list[items_list.Count > 1]
    items_list = items_list.Item.sort_values()
    return items_list

def report_column(column, df):
    reports = []
    items = items_list(df[column])
    for i in items:
        filter = df[column].str.contains(i, na=False)
        reports.append(report(df[filter], i))

    report_df = pd.concat(reports)
    return report_df

def column_final_report(column, df=df):
    report_df = report_column(column, df)
    report_df[["Applications", "Participants", "Completions"]].plot.bar(title=column)
    return report_df

def percentage(x,row_sum):
    if x == 0 or str(x) == "NaN":
        return 0 
    else:
        return f'{x} / {((x/row_sum)*100).round(1)}%'

def report_2_columns(column1, column2, df=df):
    
    items_list1 = items_list(df[column1])
    items_list2 = items_list(df[column2])

    reports = []
    for i in items_list1:
        df1 = df[df[column1].str.contains(i, na=False)]
        report_df = pd.DataFrame(index=[i])
        for j in items_list2:
            report_df[j] = len(df1[df1[column2].str.contains(j, na=False)])
        row_sum = report_df.loc[i].sum()
        report_df.loc[i] = report_df.loc[i].apply(lambda x: percentage(x,row_sum))
        reports.append(report_df)

    report_df = pd.concat(reports)
    return report_df

report_df = report_column("Season", df)

report_df.index = report_df.index.str.replace("jaro", "spring").str.replace("podzim", "fall")
report_df = report_df.rename(columns={"Completions":"Completions (6 or more sessions)"})
df.loc[df["Format"].str.contains("preferuji os", na=False), "Format"] = "in person"
df.loc[df["Format"].str.contains("preferuji on", na=False), "Format"] = "online"
